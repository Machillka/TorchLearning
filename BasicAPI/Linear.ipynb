# %%
import numpy as np
import torch
import torch.nn.functional as torchF
import torch.nn as torchNN
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline

# %%
trainX = torch.unsqueeze(torch.linspace(-1, 1, 100), dim = 1)
trainY = trainX.pow(2) + 0.2 * torch.rand(trainX.size())                # random noisy

plt.scatter(trainX.data.numpy(), trainY.data.numpy())

# %%
class Network(torchNN.Module):
    def __init__(self, featureShape, hiddenNum, outputShape) -> None:
        super(Network, self).__init__()

        self.hidden = torchNN.Linear(featureShape, hiddenNum)
        self.outputLayer = torchNN.Linear(hiddenNum, outputShape)

    def forward(self, inputData):
        x = torchF.relu(self.hidden(inputData))
        x = self.outputLayer(x)
        return x

    def TrainOneStep(self, trainX, trainY, optimizer, lossFunction):
        outputY = self.forward(trainX)
        loss = lossFunction(outputY, trainY)

        optimizer.zero_grad()                       # clear grad
        loss.backward()                             # 计算反向误差
        optimizer.step()

        return outputY, loss

# %%
model = Network(1, 10, 1)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.03)
lossFunction = torchNN.MSELoss()

fig = plt.figure()
error = 0.0
for episode in range(100):
    prediction, loss = model.TrainOneStep(trainX, trainY, optimizer, lossFunction)
    error += loss.data.numpy()
    if ( episode - 1 ) % 5 == 0:
        plt.cla()
        plt.scatter(trainX.data.numpy(), trainY.data.numpy())
        plt.plot(trainX.data.numpy(), prediction.data.numpy(), 'r-', lw=5)
        plt.text(0.5, 0, 'Loss=%.4f' % loss.data.numpy(), fontdict={'size': 20, 'color':  'red'})
        plt.pause(0.1)
        plt.show()
        display.clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#      10 error += loss.data.numpy()
#      11 if ( episode - 1 ) % 5 == 0:
# ---> 12     plt.cla()
#      13     plt.scatter(trainX.data.numpy(), trainY.data.numpy())
#      14     plt.plot(trainX.data.numpy(), prediction.data.numpy(), 'r-', lw=5)
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\pyplot.py:1251, in cla()
#    1249 """Clear the current axes."""
#    1250 # Not generated via boilerplate.py to allow a different docstring.
# -> 1251 return gca().cla()
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\axes\_base.py:1397, in _AxesBase.cla(self)
#    1395     self.__clear()
#    1396 else:
# -> 1397     self.clear()
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\axes\_base.py:1388, in _AxesBase.clear(self)
#    1386     self.cla()
#    1387 else:
# -> 1388     self.__clear()
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\axes\_base.py:1355, in _AxesBase.__clear(self)
#    1351 self.patch.set_transform(self.transAxes)
#    1353 self.set_axis_on()
# -> 1355 self.xaxis.set_clip_path(self.patch)
#    1356 self.yaxis.set_clip_path(self.patch)
#    1358 if self._sharex is not None:
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\axis.py:1110, in Axis.set_clip_path(self, path, transform)
#    1108 @_api.rename_parameter("3.8", "clippath", "path")
#    1109 def set_clip_path(self, path, transform=None):
# -> 1110     super().set_clip_path(path, transform)
#    1111     for child in self.majorTicks + self.minorTicks:
#    1112         child.set_clip_path(path, transform)
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\artist.py:802, in Artist.set_clip_path(self, path, transform)
#     800 if transform is None:
#     801     if isinstance(path, Rectangle):
# --> 802         self.clipbox = TransformedBbox(Bbox.unit(),
#     803                                        path.get_transform())
#     804         self._clippath = None
#     805         success = True
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\transforms.py:797, in Bbox.unit()
#     794 @staticmethod
#     795 def unit():
#     796     """Create a new unit `Bbox` from (0, 0) to (1, 1)."""
# --> 797     return Bbox([[0, 0], [1, 1]])
#
# File e:\.scoop\apps\python310\current\lib\site-packages\matplotlib\transforms.py:771, in Bbox.__init__(self, points, **kwargs)
#     768     raise ValueError('Bbox points must be of the form '
#     769                      '"[[x0, y0], [x1, y1]]".')
#     770 self._points = points
# --> 771 self._minpos = _default_minpos.copy()
#     772 self._ignore = True
#     773 # it is helpful in some contexts to know if the bbox is a
#     774 # default or has been mutated; we store the orig points to
#     775 # support the mutated methods
#
# KeyboardInterrupt:
